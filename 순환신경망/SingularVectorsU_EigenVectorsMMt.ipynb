# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([[0, 0.9],[0, 0.1]])

# %%
def new_axis(r):
    return np.round(np.array([[np.cos(r), -np.sin(r)],[np.sin(r), np.cos(r)]]), 2)

# %%
def horizontal_shear(m):
    return np.array([[1, m], [0, 1]])

# %%
new_axis(np.pi/2),  np.dot(new_axis(np.pi/2), x)
# Out:
# (array([[ 0., -1.],
#         [ 1.,  0.]]),
#  array([[ 0. , -0.1],
#         [ 0. ,  0.9]]))

# %%
m_90 = np.dot(new_axis(np.pi/2), x)
print(m_90)
# Out:
# [[ 0.  -0.1]
#  [ 0.   0.9]]

# %%
m_45 = np.dot(new_axis(np.pi/4), x)
m_45
# Out:
# array([[0.   , 0.568],
#        [0.   , 0.71 ]])

# %%
y = np.array([[0,0,1,1],[0,1,1,0]]) * 1/2

# %%
hs_2 = np.dot(horizontal_shear(2), y)
hs_2
# Out:
# array([[0. , 1. , 1.5, 0.5],
#        [0. , 0.5, 0.5, 0. ]])

# %%
plt.figure(figsize=(7,7))
plt.plot(x[0], x[1], c='red')
plt.plot(m_45[0], m_45[1], c='purple')
plt.plot(m_90[0], m_90[1], c='orange')

plt.plot(y[0], y[1], c='blue')
plt.plot(hs_2[0], hs_2[1], c='green')
plt.xlim([-1.5, 1.5])
plt.ylim([-1.5, 1.5])
plt.grid()
