# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
m = np.array([[0, 0], [3, 1]])

# %%
def

# %%
np.cos(0), np.cos(np.pi/2), np.cos(np.pi), np.cos(2*np.pi)
# Out:
# (1.0, 6.123233995736766e-17, -1.0, 1.0)

# %%
np.pi/2
# Out:
# 1.5707963267948966

# %%
um = np.dot(u, m)
print(um)
# Out:
# [[-2.12132034 -0.70710678]
#  [ 2.12132034  0.70710678]]

# %%
mu = np.dot(m, u)
print(mu)
# Out:
# [[ 0.          0.        ]
#  [-1.41421356 -1.41421356]]

# %%
plt.plot(m[:, 0], m[:, 1], c='red')
plt.plot(u[:, 0], u[:, 1], c='blue')
plt.plot(mu[:, 0], mu[:, 1], c='green')
plt.plot(um[:, 0], um[:, 1], c='orange')
plt.xlim([-4.5, 4.5])
plt.ylim([-4.5, 4.5])
plt.show()
